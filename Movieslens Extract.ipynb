# %%
import pandas as pd

# %%
movies_metadata = pd.read_csv("movies_metadata.csv", low_memory = False)
ratings = pd.read_csv('ratings.csv')

# %%
movies_metadata.sample(5)
# Out:
#        adult                              belongs_to_collection    budget  \
# 27845  False                                                NaN         0
# 21107  False                                                NaN         0
# 16776  False  {'id': 266846, 'name': 'Corto Maltese', 'poste...         0
# 12175  False                                                NaN         0
# 14117  False                                                NaN  30000000
#
#                                                   genres  \
# 27845                [{'id': 99, 'name': 'Documentary'}]
# 21107                     [{'id': 35, 'name': 'Comedy'}]
# 16776  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 12175                    [{'id': 37, 'name': 'Western'}]
# 14117  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#                                    homepage      id    imdb_id  \
# 27845                                   NaN  319074  tt1780871
# ...

# %%
wiki_movies_df = pd.DataFrame(wiki_movies_raw)_
wiki_movies_df.head()
# Out:
#   Input In [9]
#     wiki_movies_df = pd.DataFrame(wiki_movies_raw)_
#                                                   ^
# SyntaxError: invalid syntax
